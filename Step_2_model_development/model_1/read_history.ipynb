# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
history =np.load('../model_2/trained_model_2_history.npy', allow_pickle=True).item()

# %%
fig, ax1 = plt.subplots(1,1, figsize=(10,10), frameon=True)
ax1.plot(history['loss'])
ax1.plot(history['val_loss'])
