# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
A = np.array([-7.5, -5.3, -5.6312, -8.9128, -4.8327, -4.3879])*1e4
B = np.array([-0.2, -0.2, 0.2, 0.3, 0, 0])*1e4
C = np.array([55.8, 28.7, 27.6, 70, 16.4, 11.6])*1e4
D = np.array([-0.5736, -0.5001, -0.523, -0.5181, -0.5180, -0.4604,])*1e4
E = np.array([1.2, 1.6, 1.6, 1.4, 1.9, 1.746])
xe = np.array([0.5, 0.6314, 0.6314, 0.5403, 0.7476, 0.7156,])

PdRh_A, CuMn_A =np.array([-6.5701])*1e4, np.array([-4.4232])*1e4
PdRh_B, CuMn_B =np.array([-0.22055])*1e4, np.array([0.28438])*1e4
PdRh_C, CuMn_C =np.array([30.077])*1e4, np.array([36.976])*1e4
PdRh_D, CuMn_D =np.array([-0.2568])*1e4, np.array([-0.1339])*1e4
PdRh_E, CuMn_E =np.array([1.527]), np.array([0.9743])
PdRh_xe, CuMn_xe =np.array([0.7733]), np.array([0.68])

# %%
path = os.path.abspath("..")

# %%
fig = plt.figure(figsize=(22,12))
# plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.1, hspace=5)

gs = fig.add_gridspec(2,3)
ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])
ax3 = fig.add_subplot(gs[0,2])
ax4 = fig.add_subplot(gs[1,0])
ax5 = fig.add_subplot(gs[1,1])
ax6 = fig.add_subplot(gs[1,2])


plt.rcParams["font.family"] = "serif"
# plt.rcParams["font.size"] = 20
plt.rcParams["axes.linewidth"] = 3
plt.rcParams["lines.linewidth"] = 3
plt.rcParams["axes.edgecolor"] = "black"
# plt.rcParams["axes.labelsize"] = 28
plt.rcParams["axes.labelweight"] = "bold"


ax1.boxplot(A, vert=False, widths=0.5, patch_artist=True, boxprops=dict(facecolor="lightblue"), showmeans=False,  meanprops=dict(marker='*', markersize=25, markerfacecolor='green', markeredgecolor='green'))
ax1.set_title(r"$\alpha$", fontsize = 70, weight ='bold')
ax1.plot(PdRh_A, 1, marker='D', markersize=15,  color='blue', label='Pd-Rh')
ax1.plot(CuMn_A, 1, marker='o',  markersize=15,  color='red', label='Cu-Mn')
ax1.xaxis.get_offset_text().set_visible(True)
ax1.ticklabel_format(axis='x', style='scientific', scilimits=(0,0),useMathText=False, )
ax1.tick_params(axis='x', labelcolor='k', labelsize=50, length=8, width=3, )
ax1.xaxis.set_major_locator(plt.MaxNLocator(3))
ax1.tick_params(axis='y', left=False, right=False, labelleft=False)
ax1.xaxis.offsetText.set_fontsize(35)
ax1.xaxis.offsetText.set_weight('bold')
# ax1.legend(mode="expand",  ncol=2, loc=2, prop={'weight':'bold', 'size':'26',}, handlelength=0, frameon=False)



ax2.boxplot(B, vert=False, widths=0.5, patch_artist=True, boxprops=dict(facecolor="lightgreen"), showmeans=False,  meanprops=dict(marker='*', markersize=25, markerfacecolor='green', markeredgecolor='green'))
ax2.set_title(r"$\beta$", fontsize = 70, weight ='bold')
ax2.plot(PdRh_B, 1, marker='D', markersize=15,  color='blue', label='Pd-Rh')
ax2.plot(CuMn_B, 1, marker='o',  markersize=15,  color='red', label='Cu-Mn')
ax2.ticklabel_format(axis='x', style='scientific', scilimits=(0,0),useMathText=False, )
ax2.tick_params(axis='x', labelcolor='k', labelsize=50, length=8, width=3, )
ax2.xaxis.set_major_locator(plt.MaxNLocator(3))
ax2.tick_params(axis='y', left=False, right=False, labelleft=False)
ax2.xaxis.get_offset_text().set_visible(True)
ax2.xaxis.offsetText.set_fontsize(35)
ax2.xaxis.offsetText.set_weight('bold')
# ax2.legend(mode="expand",  ncol=2, loc=2, prop={'weight':'bold', 'size':'26',}, handlelength=0, frameon=False)


ax3.boxplot(C, vert=False, widths=0.5, patch_artist=True, boxprops=dict(facecolor="lightyellow"), showmeans=False,  meanprops=dict(marker='*', markersize=25, markerfacecolor='green', markeredgecolor='green'))
ax3.set_title(r"$\gamma$", fontsize = 70, weight ='bold')
ax3.plot(PdRh_C, 1, marker='D', markersize=15,  color='blue', label='Pd-Rh')
ax3.plot(CuMn_C, 1, marker='o',  markersize=15,  color='red', label='Cu-Mn')
ax3.ticklabel_format(axis='x', style='scientific', scilimits=(0,0),useMathText=False, )
ax3.tick_params(axis='x', labelcolor='k', labelsize=50, length=8, width=3, )
ax3.xaxis.set_major_locator(plt.MaxNLocator(3))
ax3.tick_params(axis='y', left=False, right=False, labelleft=False)
ax3.xaxis.get_offset_text().set_visible(True)
ax3.xaxis.offsetText.set_fontsize(35)
ax3.xaxis.offsetText.set_weight('bold')
# ax3.legend(mode="expand",  ncol=2, loc=2, prop={'weight':'bold', 'size':'26',}, handlelength=0, frameon=False)


ax4.boxplot(D, vert=False, widths=0.5, patch_artist=True, boxprops=dict(facecolor="lightcoral"), showmeans=False,  meanprops=dict(marker='*', markersize=25, markerfacecolor='green', markeredgecolor='green'))
ax4.set_title(r"$\delta$", fontsize = 70, weight ='bold')
ax4.plot(PdRh_D, 1, marker='D', markersize=15,  color='blue', label='Pd-Rh')
ax4.plot(CuMn_D, 1, marker='o',  markersize=15,  color='red', label='Cu-Mn')
ax4.ticklabel_format(axis='x', style='scientific', scilimits=(0,0),useMathText=False, )
ax4.tick_params(axis='x', labelcolor='k', labelsize=50, length=8, width=3, )
ax4.xaxis.set_major_locator(plt.MaxNLocator(3))
ax4.tick_params(axis='y', left=False, right=False, labelleft=False)
ax4.xaxis.get_offset_text().set_visible(True)
ax4.xaxis.offsetText.set_fontsize(35)
ax4.xaxis.offsetText.set_weight('bold')
# ax4.legend(mode="expand",  ncol=2, loc=2, prop={'weight':'bold', 'size':'26',}, handlelength=0, frameon=False)



ax5.boxplot(E, vert=False, widths=0.5, patch_artist=True, boxprops=dict(facecolor="lightpink"), showmeans=False,  meanprops=dict(marker='*', markersize=25, markerfacecolor='green', markeredgecolor='green'))
ax5.set_title(r"$\epsilon$", fontsize = 70, weight ='bold')
ax5.plot(PdRh_E, 1, marker='D', markersize=15,  color='blue', label='Pd-Rh')
ax5.plot(CuMn_E, 1, marker='o',  markersize=15,  color='red', label='Cu-Mn')
ax5.ticklabel_format(axis='x', style='scientific', scilimits=(0,0),useMathText=False, )
ax5.tick_params(axis='x', labelcolor='k', labelsize=50, length=8, width=3, )
ax5.xaxis.set_major_locator(plt.MaxNLocator(3))
ax5.tick_params(axis='y', left=False, right=False, labelleft=False)
ax5.xaxis.get_offset_text().set_visible(True)
ax5.xaxis.offsetText.set_fontsize(25)
ax5.xaxis.offsetText.set_weight('bold')
# ax5.legend(mode="expand",  ncol=2, loc=2, prop={'weight':'bold', 'size':'26',}, handlelength=0, frameon=False)


ax6.boxplot(xe, vert=False, widths=0.5, patch_artist=True, boxprops=dict(facecolor="lightgray"), showmeans=False,  meanprops=dict(marker='*', markersize=25, markerfacecolor='green', markeredgecolor='green'))
ax6.set_title(r"$c_{eq}$", fontsize = 70, weight ='bold')
ax6.plot(PdRh_xe, 1, marker='D', markersize=15,  color='blue', label='Pd-Rh')
ax6.plot(CuMn_xe, 1, marker='o',  markersize=15,  color='red', label='Cu-Mn')
ax6.ticklabel_format(axis='x', useMathText=False, )
ax6.tick_params(axis='x', labelcolor='k', labelsize=50, length=8, width=3, )
ax6.xaxis.set_major_locator(plt.MaxNLocator(3))
ax6.tick_params(axis='y', left=False, right=False, labelleft=False)
ax6.xaxis.get_offset_text().set_visible(True)
ax6.xaxis.offsetText.set_fontsize(25)
ax6.xaxis.offsetText.set_weight('bold')
# ax6.legend(mode="expand",  ncol=2, loc=2, prop={'weight':'bold', 'size':'26',}, handlelength=0, frameon=False)

ax5.legend(mode="expand",  ncol=2, loc=(0,1.3), prop={'weight':'bold', 'size':'37',}, handlelength=0, frameon=True,facecolor='none')
# ax5.text('')

# mean_line = mlines.Line2D([], [], color='green', marker='*', markersize=25,  label='Mean')
# # Add the custom legend entry to the legend
# ax4.legend(handles=[mean_line])




plt.subplots_adjust(hspace=0.4)

# Save and display the plot
# plt.savefig("box_plots.png", dpi=300)

ax1.grid(), ax2.grid(), ax3.grid(), ax4.grid(), ax5.grid(), ax6.grid()
for label in ax1.get_xticklabels(): label.set_fontweight('bold')
for label in ax2.get_xticklabels(): label.set_fontweight('bold')
for label in ax3.get_xticklabels(): label.set_fontweight('bold')
for label in ax4.get_xticklabels(): label.set_fontweight('bold')
for label in ax5.get_xticklabels(): label.set_fontweight('bold')
for label in ax6.get_xticklabels(): label.set_fontweight('bold')

  
plt.tight_layout()

plt.savefig(path+'/Step_6_Appendix_And_Graphical_Abstract/figures/coefficients.png', transparent=True)
plt.show()

# %% [markdown]
# ## Appendix variation in G

# %%
fig = plt.figure(figsize=(24,18))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.2, hspace=0.8)


gs = fig.add_gridspec(2,3)
ax1 = fig.add_subplot(gs[0, 0])
ax2 = fig.add_subplot(gs[0, 1])
ax3 = fig.add_subplot(gs[0, 2])
ax4 = fig.add_subplot(gs[1, 0])
ax5 = fig.add_subplot(gs[1, 1])
ax6 = fig.add_subplot(gs[1, 2])

""" General values A, B, C, D, E, xe, Th = -5.50, 0.0, 27.5, -0.5, 1.5, 0.65, 10000 """

X = np.arange(0.0, 1.0, 0.001)


A1, A2, B, C, D, E, xe, Th = -5.50e4, -2.25e4, 0.0e4, 27.5e4, -0.5e4, 1.5, 0.65, 1

G_A1 = Th * (A1*(E*X - xe)**2 + B*(E*X - xe) + C*(E*X - xe)**4 + D)
G_A2 = Th * (A2*(E*X - xe)**2 + B*(E*X - xe) + C*(E*X - xe)**4 + D)
ax1.plot(X, G_A1, color='red', linewidth=10, label=r"$\alpha$ = %se4 J/mol"%(A1/10000))
ax1.plot(X, G_A2, color='green', linewidth=10, label=r"$\alpha$ = %se4 J/mol"%(A2/10000))
ax1.grid(alpha=0.5)
ax1.tick_params(axis='y', labelcolor='k', labelsize=50)
ax1.tick_params(axis='x', labelcolor='k', labelsize=50)
ax1.set_xlabel("c$_{A_i}$", fontsize=70, weight='bold')
ax1.set_ylabel("G (J/mol)", fontsize=70)
ax1.set_xlim(0, 1)
ax1.set_ylim(-11000, 0)
ax1.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=False)
ax1.xaxis.set_major_locator(plt.MaxNLocator(3))
ax1.yaxis.set_major_locator(plt.MaxNLocator(3))
ax1.yaxis.offsetText.set_fontsize(50)
for label in ax1.get_xticklabels(): label.set_fontweight('bold')
for label in ax1.get_yticklabels(): label.set_fontweight('bold')
ax1.legend(loc=4, prop={'weight':'bold', 'size':'25'},  handlelength=0.75, frameon=False).get_frame().set_facecolor('none')
ax1.set_title(r'$\alpha$', fontsize=100, weight=20)
ax1.text(-0.3,1000,"(a)", fontsize=70, weight='bold')
#####################################


A, B1, B2, B3, C, D, E, xe, Th = -5.50e4, -0.5e4, +0.5e4, 0e4, 27.5e4, -0.5e4, 1.5, 0.65, 1

G_B1 = Th * (A*(E*X - xe)**2 + B1*(E*X - xe) + C*(E*X - xe)**4 + D)
G_B2 = Th * (A*(E*X - xe)**2 + B2*(E*X - xe) + C*(E*X - xe)**4 + D)
G_B3 = Th * (A*(E*X - xe)**2 + B3*(E*X - xe) + C*(E*X - xe)**4 + D)
ax2.plot(X, G_B1, color='magenta', linewidth=10, label=r"$\beta$ = %se3 J/mol"%(B1/1e3))
ax2.plot(X, G_B3, color='black', linestyle='--', linewidth=7, label=r"$\beta$ = %s"%B3)
ax2.plot(X, G_B2, color='lime', linewidth=10, label=r"$\beta$ = %se3 J/mol"%(B2/1e3))
ax2.grid(alpha=0.5)
ax2.tick_params(axis='y', labelcolor='k', labelsize=50)
ax2.tick_params(axis='x', labelcolor='k', labelsize=50)
ax2.set_xlabel("c$_{A_i}$", fontsize=70, weight='bold')
# ax2.set_ylabel("G (J/mol)", fontsize=70)
ax2.set_xlim(0, 1)
ax2.set_ylim(-11000, 0)
ax2.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=False)
ax2.xaxis.set_major_locator(plt.MaxNLocator(3))
ax2.yaxis.set_major_locator(plt.MaxNLocator(3))
ax2.tick_params(axis='y', labelcolor='black', labelsize=65, left=True, length = 8, width=5, right=False, labelleft=False)
ax2.yaxis.offsetText.set_fontsize(50)
for label in ax2.get_xticklabels(): label.set_fontweight('bold')
for label in ax2.get_yticklabels(): label.set_fontweight('bold')
ax2.legend(loc=(0.16,0.7), prop={'weight':'bold', 'size':'25'}, handlelength=0.75,  frameon=False).get_frame().set_facecolor('none')
ax2.set_title(r'$\beta$', fontsize=100, weight=20)
ax2.text(-0.15,1000,"(b)", fontsize=70, weight='bold')
######################################

A, B, C1, C2, D, E, xe, Th = -5.50e4, 0.0e4, 27.5e4, 13.75e4, -0.5e4, 1.5, 0.65, 1
G_C1 = Th * (A*(E*X - xe)**2 + B*(E*X - xe) + C1*(E*X - xe)**4 + D)
G_C2 = Th * (A*(E*X - xe)**2 + B*(E*X - xe) + C2*(E*X - xe)**4 + D)
ax3.plot(X, G_C1, color='aqua', linewidth=10, label=r"$\gamma$ = %se5 J/mol"%(round((C1/1e5),2)))
ax3.plot(X, G_C2, color='brown', linewidth=10, label=r"$\gamma$ = %se5 J/mol"%(round((C2/1e5),2)))

ax3.grid(alpha=0.5)
ax3.tick_params(axis='y', labelcolor='k', labelsize=50)
ax3.tick_params(axis='x', labelcolor='k', labelsize=50)
ax3.set_xlabel("c$_{A_i}$", fontsize=70, weight='bold')
ax3.set_xlim(0, 1)
ax3.set_ylim(-11000, 0)
ax3.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=False)
ax3.xaxis.set_major_locator(plt.MaxNLocator(3))
ax3.yaxis.set_major_locator(plt.MaxNLocator(3))
ax3.tick_params(axis='y', labelcolor='black', labelsize=65, left=True, length = 8, width=5, right=False, labelleft=False)
ax3.yaxis.offsetText.set_fontsize(50)
for label in ax3.get_xticklabels(): label.set_fontweight('bold')
for label in ax3.get_yticklabels(): label.set_fontweight('bold')
ax3.legend(loc=(0.16,0.7), prop={'weight':'bold', 'size':'25'}, handlelength=0.75,  frameon=False).get_frame().set_facecolor('none')
ax3.set_title(r'$\gamma$', fontsize=100, weight=20)
ax3.text(-0.15,1000,"(c)", fontsize=70, weight='bold')

#########################################

A, B, C, D1, D2, E, xe, Th = -5.50e4, 0.0e4, 27.5e4, -0.5e4, -0.75e4, 1.5, 0.65, 1

G_D1 = Th * (A*(E*X - xe)**2 + B*(E*X - xe) + C*(E*X - xe)**4 + D1)
G_D2 = Th * (A*(E*X - xe)**2 + B*(E*X - xe) + C*(E*X - xe)**4 + D2)
ax4.plot(X, G_D1, color='tomato', linewidth=10, label=r"$\delta$ = %se3 J/mol"%(D1/1e3))
ax4.plot(X, G_D2, color='darkorchid', linewidth=10, label=r"$\delta$ = %se3 J/mol"%(D2/1e3))

ax4.grid(alpha=0.5)
ax4.tick_params(axis='y', labelcolor='k', labelsize=50)
ax4.tick_params(axis='x', labelcolor='k', labelsize=50)
ax4.set_ylabel("G (J/mol)", fontsize=70)
ax4.set_xlabel("c$_{A_i}$", fontsize=70, weight='bold')
ax4.set_xlim(0, 1)
ax4.set_ylim(-11000, 0)
ax4.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=False)
ax4.xaxis.set_major_locator(plt.MaxNLocator(3))
ax4.yaxis.set_major_locator(plt.MaxNLocator(3))
ax4.yaxis.offsetText.set_fontsize(50)
for label in ax4.get_xticklabels(): label.set_fontweight('bold')
for label in ax4.get_yticklabels(): label.set_fontweight('bold')
ax4.legend(loc=(0.16,0.7), prop={'weight':'bold', 'size':'25'}, handlelength=0.75,  frameon=False).get_frame().set_facecolor('none')
ax4.set_title(r'$\delta$', fontsize=100, weight=20)
ax4.text(-0.3,1000,"(d)", fontsize=70, weight='bold')

#########################################

A, B, C, D, E1, E2, xe, Th = -5.50e4, 0.0e4, 27.5e4, -0.5e4, 1.5, 3.0, 0.65, 1

G_E1 = Th * (A*(E1*X - xe)**2 + B*(E1*X - xe) + C*(E1*X - xe)**4 + D)
G_E2 = Th * (A*(E2*X - xe)**2 + B*(E2*X - xe) + C*(E2*X - xe)**4 + D)

ax5.plot(X, G_E1, color='navy', linewidth=10, label=r"$\epsilon$ = %s "%E1)
ax5.plot(X, G_E2, color='gold', linewidth=10, label=r"$\epsilon$ = %s "%E2)
ax5.grid(alpha=0.5)
ax5.tick_params(axis='y', labelcolor='k', labelsize=50)
ax5.tick_params(axis='x', labelcolor='k', labelsize=50)
ax5.set_xlabel("c$_{A_i}$", fontsize=70, weight='bold')
ax5.set_xlim(0, 1)
ax5.set_ylim(-11000, 0)
ax5.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=False)
ax5.xaxis.set_major_locator(plt.MaxNLocator(3))
ax5.yaxis.set_major_locator(plt.MaxNLocator(3))
ax5.tick_params(axis='y', labelcolor='black', labelsize=65, left=True, length = 8, width=5, right=False, labelleft=False)
ax5.yaxis.offsetText.set_fontsize(50)
for label in ax5.get_xticklabels(): label.set_fontweight('bold')
for label in ax5.get_yticklabels(): label.set_fontweight('bold')
ax5.legend(loc=4, prop={'weight':'bold', 'size':'25'}, handlelength=0.75, frameon=False).get_frame().set_facecolor('none')
ax5.set_title(r'$\epsilon$', fontsize=100, weight=20)
ax5.text(-0.15,1000,"(e)", fontsize=70, weight='bold')

####################################

A, B, C, D, E, xe1, xe2, Th = -5.50e4, 0.0e4, 27.5e4, -0.5e4, 1.5, 0.65, 0.95, 1

G_xe1 = Th * (A*(E*X - xe1)**2 + B*(E*X - xe1) + C*(E*X - xe1)**4 + D)
G_xe2 = Th * (A*(E*X - xe2)**2 + B*(E*X - xe2) + C*(E*X - xe2)**4 + D)

ax6.plot(X, G_xe1, color='blue', linewidth=10, label=r"$c_{eq}$ = %s "%xe1)
ax6.plot(X, G_xe2, color='darkorange', linewidth=10, label=r"$c_{eq}$ = %s "%xe2)

ax6.grid(alpha=0.5)
ax6.tick_params(axis='y', labelcolor='k', labelsize=50)
ax6.tick_params(axis='x', labelcolor='k', labelsize=50)
ax6.set_xlabel("c$_{A_i}$", fontsize=70, weight='bold')
ax6.set_xlim(0, 1)
ax6.set_ylim(-11000, 0)
ax6.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=False)
ax6.xaxis.set_major_locator(plt.MaxNLocator(3))
ax6.yaxis.set_major_locator(plt.MaxNLocator(3))
ax6.tick_params(axis='y', labelcolor='black', labelsize=65, left=True, length = 8, width=5, right=False, labelleft=False)
ax6.yaxis.offsetText.set_fontsize(50)
for label in ax6.get_xticklabels(): label.set_fontweight('bold')
for label in ax6.get_yticklabels(): label.set_fontweight('bold')
ax6.legend(loc=4, prop={'weight':'bold', 'size':'25'}, handlelength=0.75, frameon=False).get_frame().set_facecolor('none')
ax6.set_title(r'$c_{eq}$', fontsize=100, weight=20)
ax6.text(-0.15,1000,"(f)", fontsize=70, weight='bold')

plt.tight_layout()
plt.savefig(path+'/Step_6_Appendix_And_Graphical_Abstract/figures/appendix.png', transparent=True)

plt.show()

# %% [markdown]
# ## Graphical Abstract

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.arange(0.0, 1.0, 0.001)

""" General values A, B, C, D, E, xe, Th = -5.50, 0.0, 27.5, -0.5, 1.5, 0.65, 10000 """

A, B1, B2, B3, C, D, E, xe, Th = -6.350e4, -0.48e4, +0.53e4, 0e4, 23.75e4, -0.375e4, 1.25, 0.55, 1



G_B1 = Th * (A*(E*X - xe)**2 + B1*(E*X - xe) + C*(E*X - xe)**4 + D)
G_B2 = Th * (A*(E*X - xe)**2 + B2*(E*X - xe) + C*(E*X - xe)**4 + D)
G_B3 = Th * (A*(E*X - xe)**2 + B3*(E*X - xe) + C*(E*X - xe)**4 + D)


plt.rcParams["figure.figsize"] = (8, 8)
plt.plot(X, G_B1, color='red', linewidth=10, label=r"$\beta$ = %se3 J/mol"%(B1/1e3))
plt.plot(X, G_B3, color='black', linestyle='--', linewidth=7, label=r"$\beta$ = %s"%B3)
plt.plot(X, G_B2, color='green', linewidth=10, label=r"$\beta$ = %se3 J/mol"%(B2/1e3))




plt.xticks(fontsize=50, weight='bold')
plt.xlabel("c$_{A_i}$", fontsize=70, weight='bold')
plt.yticks(fontsize=50, weight='bold')
plt.ylabel("G (J/mol)", fontsize=70)
plt.xlim(0, 1)
plt.ylim(-11000, 0)
plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useMathText=False)


plt.gca().xaxis.set_major_locator(plt.MaxNLocator(3))
plt.gca().yaxis.set_major_locator(plt.MaxNLocator(3))

plt.gca().yaxis.offsetText.set_fontsize(50)

point1 = [X[np.argmin(G_B1[:300])], min(G_B1[:300])]
point2 = [X[500 + np.argmin(G_B1[500:])], min(G_B1[500:])]
point3 = [X[np.argmin(G_B2[:300])], min(G_B2[:300])]
point4 = [X[500 + np.argmin(G_B2[500:])], min(G_B2[500:])]
point5 = [X[np.argmin(G_B3[:300])], min(G_B3[:300])]
point6 = [X[500 + np.argmin(G_B3[500:])], min(G_B3[500:])]


x_B1 = [point1[0], point2[0]]
y_B1 = [point1[1], point2[1]]
x_B2 = [point3[0], point4[0]]
y_B2 = [point3[1], point4[1]]
x_B3 = [point5[0], point6[0]]
y_B3 = [point5[1], point6[1]]


plt.legend(loc=(0.2,0.7), prop={'weight':'bold', 'size': 20}, handlelength=0.75, frameon=False).get_frame().set_facecolor('none')

plt.grid(alpha=0)
plt.tight_layout()


plt.savefig(path+'/Step_6_Appendix_And_Graphical_Abstract/figures/graphical_abstract.png', transparent=True)

plt.show()
